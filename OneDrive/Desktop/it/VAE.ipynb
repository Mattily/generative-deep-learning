# %%
# Import necessary libraries
import numpy as np
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras.losses import binary_crossentropy
from keras import backend as K

# Parameters
input_dim = 784
intermediate_dim = 64
latent_dim = 2

# Encoder
inputs = Input(shape=(input_dim,))
h = Dense(intermediate_dim, activation='relu')(inputs)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

def sampling(args):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# Decoder
decoder_h = Dense(intermediate_dim, activation='relu')
decoder_mean = Dense(input_dim, activation='sigmoid')
h_decoded = decoder_h(z)
x_decoded_mean = decoder_mean(h_decoded)

# VAE model
vae = Model(inputs, x_decoded_mean)

# Loss function
xent_loss = binary_crossentropy(inputs, x_decoded_mean)
kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
vae_loss = K.mean(xent_loss + kl_loss)

vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')
vae.summary()

# Training data
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))).astype('float32') / 255
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:]))).astype('float32') / 255

# Train the VAE
vae.fit(x_train, epochs=50, batch_size=256, validation_data=(x_test, None))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  dense (Dense)                  (None, 64)           50240       ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 2)            130         ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 2)            130         ['dense[0][0]']
#
#  lambda (Lambda)                (None, 2)            0           ['dense_1[0][0]',
#                                                                   'dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           192         ['lambda[0][0]']
#
#  dense_4 (Dense)                (None, 784)          50960       ['dense_3[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['dense_2[0][0]']
#  da)
#
#  tf.math.square (TFOpLambda)    (None, 2)            0           ['dense_1[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 2)            0           ['tf.__operators__.add[0][0]',
#                                                                   'tf.math.square[0][0]']
#
#  tf.math.exp (TFOpLambda)       (None, 2)            0           ['dense_2[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 784)          0           ['input_1[0][0]']
#
#  tf.convert_to_tensor (TFOpLamb  (None, 784)         0           ['dense_4[0][0]']
#  da)
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.math.subtract[0][0]',
#  )                                                                'tf.math.exp[0][0]']
#
#  tf.keras.backend.binary_crosse  (None, 784)         0           ['tf.cast[0][0]',
#  ntropy (TFOpLambda)                                              'tf.convert_to_tensor[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.math.reduce_mean (TFOpLambd  (None,)             0           ['tf.keras.backend.binary_crossen
#  a)                                                              tropy[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None,)              0           ['tf.math.reduce_sum[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None,)             0           ['tf.math.reduce_mean[0][0]',
#  mbda)                                                            'tf.math.multiply[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  ()                  0           ['tf.__operators__.add_1[0][0]']
#  bda)
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.reduce_mean_1[0][0]']
#
# ==================================================================================================
# Total params: 101,652
# Trainable params: 101,652
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 47
#      44 vae.summary()
#      46 # Training data
# ---> 47 (x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
#      48 x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))).astype('float32') / 255
#      49 x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:]))).astype('float32') / 255
#
# NameError: name 'keras' is not defined
